% %% [markdown]
% # T3.4 (Corrigir ainda)
%
% A função $φ(x)=x^2−x+0.4316$ possui dois pontos fixos, já que a equação $φ(x)=x$ é a equação do segundo grau $x^2−2x+0.4316=0$ em que $Δ=4(1−0.4316)>0$.
%
% Faça iterações $x_{k+1}=φ(x_k)$ começando com $x_0=0$ e utilizando a máxima precisão disponível, e digite abaixo o resultado encontrado para as iterações requeridas com 8 algarismos significativos.
%
% Diga o valor de $x_{100}$, $x_{101}$, $x_{102}$ e $x_{103}$, e diga se estão convergindo.

% %% [markdown]
% ## Resolução
%
% Como estamos lidando com uma iteração com a função auxiliar $φ$, faremos:

% %%
% y = @(x) x^2 - 2*x + 0.4316;
y = @(x) x^2 - x + 0.4316;
x0 = 0;
showSteps = true;

[x] = metodoIterativo(y, x0, 105, showSteps);
% Out:
% x_1 at 0 iterations is :
%  0.43159999999999998366
% x_2 at 1 iterations is :
%  0.18627855999999998193
% x_3 at 2 iterations is :
%  0.28002114191567362145
% x_4 at 3 iterations is :
%  0.22999069800408417086
% x_5 at 4 iterations is :
%  0.25450502316432166428
% x_6 at 5 iterations is :
%  0.24186778365155020554
% x_7 at 6 iterations is :
%  0.24823224111696287619
% x_8 at 7 iterations is :
%  0.24498700441298709718
% x_9 at 8 iterations is :
%  0.24663162791826184761
% x_10 at 9 iterations is :
%  0.24579553197135009523
% x_11 at 10 iterations is :
%  0.24621991156572886617
% x_12 at 11 iterations is :
%  0.24600433328570647795
% x_13 at 12 iterations is :
%  0.24611379870963845384
% x_14 at 13 iterations is :
%  0.24605820320564997239
% x_15 at 14 iterations is :
%  0.24608643615914294056
% x_16 at 15 iterations is :
%  0.24607209790236497793
% x_17 at 16 iterations is :
%  0.24607937946370611604
% x_18 at 17 iterations is :
%  0.24607568153353653884
% x_19 at 18 iterations is :
% ...

% %%
# exemplo minha solução para o exercício 1
y(0.2460769270)
% Out:
% ans = 0.246076927001763

% %%
# exemplo soluçao do professor
y(0.65696269)
% Out:
% ans = 0.206237286052036
