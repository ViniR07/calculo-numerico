% %% [markdown]
% # T3.3 (Correto)
%
% Considere o problema de encontrar a solução numérica da equação
%
% - $e^{−x}=x−1$.
%
% utilizando a função de iteração $φ(x)=e^{−x}+1$ a partir do chute inicial $x_0=0$, e critério de parada quando as primeiras p casas decimais de duas iterações consecutivas coincidirem.
%
% Determine, para cada  p abaixo, o número de iterações necessárias e o valor do último iterado com exatamente 14 algarismos significativos.

% %% [markdown]
% ## Resolução
%
% A questão nos pede para iterar encima da função auxiliar. Tais iteradas vêm dos Métodos Iterativos para Determinar Zero de Funções.
%
% Os quais se baseiam em:
%
% - Um "palpite" inicial $x_0$;
% - Uma função auxiliar φ ("função de iteração": $x_{k+1} = φ(x_k)$);
% - Análise da convergência ($x_k \rightarrow x^*$, quando $k \rightarrow \infty$);
% - Critério de parada.
%
% Logo, nossa iteração se baseia em $x_{k+1} = φ(x_k)$.
%
% Desta, analizaremos o critério de parada proposto.

% %%
y = @(x) e^-x + 1;
x0 = 0;
showSteps = true;

[x] = metodoIterativo(y, x0, 80, showSteps);
% Out:
% x_1 at 0 iterations is :
%  2.000000000000000000000000
% x_2 at 1 iterations is :
%  1.135335283236612813340116
% x_3 at 2 iterations is :
%  1.321314371949521948579331
% x_4 at 3 iterations is :
%  1.266784417465106837852318
% x_5 at 4 iterations is :
%  1.281736112489515688750430
% x_6 at 5 iterations is :
%  1.277555015195193544030872
% x_7 at 6 iterations is :
%  1.278717929152321408636794
% x_8 at 7 iterations is :
%  1.278393992574099247150343
% x_9 at 8 iterations is :
%  1.278484189179652563694845
% x_10 at 9 iterations is :
%  1.278459071983848227560543
% x_11 at 10 iterations is :
%  1.278466066182719629296116
% x_12 at 11 iterations is :
%  1.278464118542484984075713
% x_13 at 12 iterations is :
%  1.278464660890934245784933
% x_14 at 13 iterations is :
%  1.278464509866098275381319
% x_15 at 14 iterations is :
%  1.278464551921158154357272
% x_16 at 15 iterations is :
%  1.278464540210315192325652
% x_17 at 16 iterations is :
%  1.278464543471369729843445
% ...
